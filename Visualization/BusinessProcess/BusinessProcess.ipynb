# %% [markdown]
# #### This Notebook contains some Graphiviz and diagrams code

# %%
import pandas as pd
import graphviz

# %%
# You can use whatever format required , For My case Pdf is right choice.

dot = graphviz.Digraph(format='png', graph_attr={'label': 'Balance Scorecard Financial Datasoruces'})

dot.node('A', 'Finance', shape='box', style="filled", fillcolor='#D69CB4')
dot.node('1', 'BS-F-001', shape='rarrow', style="filled", color='lightblue')
dot.node('2', 'BS-F-002', shape='rarrow', style="filled", color='lightblue')
dot.node('3', 'BS-F-003', shape='rarrow', style="filled", color='lightblue')
dot.node('5', 'DataSoruce-1', shape='rect', style="filled", fillcolor='#BFA29B')
dot.node('6', 'DataSoruce-2', shape='rect', style="filled", fillcolor='#D69CB4')
dot.node('7', 'DataSoruce-3', shape='box', style="filled", fillcolor='#D69CB4')
dot.node('8', 'DataSoruce-4', shape='box', style="filled", fillcolor='#D69CB4')
dot.node('b', 'Employee \n Table', shape='cylinder' ,  style="filled", fillcolor='#aff0cd')
dot.node('c', 'ERP \n Table', shape='cylinder' ,  style="filled", fillcolor='#aff0cd')
dot.node('e', 'Projects \n Table', shape='cylinder' ,  style="filled", fillcolor='#aff0cd')
dot.node('d', 'Power BI ', shape='note' ,  style="filled", fillcolor='#ede3bb')


dot.edges(['A1','A2', 'A3', '15', '16', '25' , '26', '37', '38', '5b', '8c', '6c', 'bd',  'cd', '7e', 'ed'])
dot.attr(rankdir='LR')  
dot.render(filename='BalanceScoreCard-KPI')
dot

# %% [markdown]
# ### Below is small pice of code producing the folder hirarchy for some Automated reprots to be submitted.

# %%
dot = graphviz.Digraph(format='png')

dot.node('z','Department Folder Hierarchy', shape='plaintext')
dot.node('5','00 First- Level', bgcolor='red', shape='box')
dot.node('5','00 First- Level', bgcolor='red', shape='box')
dot.node('1','00 Reporting',shape='box' , color='red')
dot.node('2','01 Monthly', shape='box', color='greenyellow')
dot.node('3','02 Bi Weekly', shape='box', color='greenyellow')
dot.node('4','03 Weekly', shape='box', color='greenyellow')
dot.node('6','August 2023', shape='box', color='blue4')
dot.node('7','September 2023', shape='box', color='blue4')
dot.node('8','August 2023', shape='box', color='blue4')
dot.node('9','September 2023', shape='box', color='blue4')
dot.node('8','August 2023', shape='box', color='blue4')
dot.node('A','September 2023', shape='box', color='blue4')
dot.node('B','Week 1', shape='box', color='darkgreen')
dot.node('C','Week 2', shape='box', color='darkgreen')
dot.node('D','Week 3', shape='box', color='darkgreen')
dot.node('E','Week 4', shape='box', color='darkgreen')
dot.edges(['z5','51','12','13', '14', '26', '27', '38', '39','4A', 'AB', 'AC', 'AD', 'AE' ])

dot.render(filename='FolderHirarchy')
dot

# %%
dot = graphviz.Digraph('User-Logs-Analysis', format='png')

dot.node('1' , 'Export Data on 08-December', shape='oval', style = 'filled', color='lightgrey')
dot.node('2', 'Export User Logs Details from D 365 ', shape='box')
dot.node('3', 'Export Licence Data in D 365', shape='box')
dot.node('4', 'Process with provided criteria', shape='box', style = 'filled', color='lightgrey')
dot.node('5', 'First meeting with middle management 12-December', shape='box')
dot.node('6', 'Second meeting with higher management 22-December', shape='box')
dot.node('7', 'Comments Adding variables to Main dashboard', shape='house', style = 'filled', color='lightgrey')
dot.node('8', 'Next Report Before 30 IA', shape='oval')
dot.edges(['12', '23', '34', '45' , '56' , '67', '78'])

dot.render(filename='ProcessFlow')
dot
